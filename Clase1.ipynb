# %% [markdown]
# Primera clase en colab

# %%
print(edad1)#print es para imprimir o mostrar los resultados
# Out:
# 23

# %%
edad1= 23
nacimiento= "Barranquilla"
residencia="Medellin"
nombre= "Maria"
print(nombre ,"tiene", edad1, "años")
print("Es de", nacimiento, "y vive en", residencia)
# Out:
# Maria tiene 23 años
# Es de Barranquilla y vive en Medellin

# %%
nombre1=input("Ingrese su nombre ")
print("Su nombre es:",nombre1)
# Out:
# Ingrese su nombre Erick
# Su nombre es: Erick

# %%
edad2=input("Ingrese la edad ")#Input es para obtener datos del usuario o para pedirle que ingrese un valor
# Out:
# Ingrese la edad 17

# %%
print(type(edad2))#tipe sirve para conocer un tipo de variable es una variable
# Out:
# <class 'str'>

# %%
a=5
b=-8.0
c="hola"
d="1560"
e= True

# %%
#convertir de entero a flotante(decimal)
a= float(a)
print(a)
# Out:
# 5.0

# %%
#convertir de flotante(decimal) a entero
b=int(b)
print(b)
# Out:
# -8

# %%
#De caracter a entero o flotante
f=int(d)
print("A entero ",f)
g=float(d)
print("A flotante",g)
# Out:
# A entero  1560
# A flotante 1560.0

# %%
print("Ingrese su nombre")#Ejemplo de promedo de edades
Nombre1=input()
print("Ingrese su edad")
edad1=int(input())
print("Ingrese su nombre")
Nombre2=input( )
print("Ingrese la edad")
edad2=int(input())
print("Ingrese su nombre")
Nombre3=input()
print("Ingrese su edad")
edad3=int(input())
promedio= (edad1+edad2+edad3)/3

print("El promedio de edades es: ", promedio)
print(Nombre1, "tiene una edad de: ", edad1, "años")
print(Nombre2, "tiene una edad de: ", edad2, "años")
print(Nombre1, "tiene una edad de: ", edad3, "años")
# Out:
# Ingrese su nombre
# Erick
# Ingrese su edad
# 89
# Ingrese su nombre
# eriifj
# Ingrese la edad
# 89
# Ingrese su nombre
# ieie
# Ingrese su edad
# 89
# El promedio de edades es:  89.0
# Erick tiene una edad de:  89 años
# eriifj tiene una edad de:  89 años
# Erick tiene una edad de:  89 años
